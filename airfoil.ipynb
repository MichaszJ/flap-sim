# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('NACA63A418.csv')
data
# Out:
#            0      0.1       0.2     0.3
# 0     0.2474   1.4409    0.7526 -1.2160
# 1     0.4654   1.7753    1.0346 -1.4591
# 2     0.9185   2.3380    1.5815 -1.8554
# 3     2.0990   3.4230    2.9010 -2.5793
# 4     4.5367   4.9877    5.4633 -3.5453
# 5     7.0132   6.1788    7.9868 -4.2335
# 6     9.5085   7.1519   10.4915 -4.7678
# 7    14.5291   8.6762   15.4709 -5.5534
# 8    19.5728   9.8003   20.4272 -6.0799
# 9    24.6297  10.6164   25.3703 -6.4108
# 10   29.6952  11.1640   30.3048 -6.5697
# 11   34.7662  11.4444   35.2338 -6.5488
# 12   39.8392  11.4778   40.1608 -6.3623
# 13   44.9115  11.2766   45.0885 -6.0198
# 14   49.9800  10.8717   50.0200 -5.5515
# 15   55.0429  10.2894   54.9571 -4.9848
# 16   60.0983   9.5506   59.9017 -4.3442
# 17   65.1451   8.6738   64.8549 -3.6550
# 18   70.1830   7.6788   69.8170 -2.9483
# 19   75.2137   6.5901   74.7863 -2.2695
# 20   80.2556   5.4120   79.7444 -1.6733
# 21   85.2493   4.1029   84.7507 -1.2173
# ...

# %%
x = data.transpose().iloc[0]
y1 = data.transpose().iloc[1]
y2 = data.transpose().iloc[2]
y3 = data.transpose().iloc[3]

# %%
plt.figure(dpi=260)
plt.plot(x, y1)
plt.plot(x, y2, alpha=0)
plt.plot(x, y3)

plt.show()
